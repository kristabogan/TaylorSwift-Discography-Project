# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('tsrankings.csv')
df = df.drop(0)
print(df.head())
# Out:
#       Album                          Song  Total Weighted Score  Enjoyability  \
# 1  folklore               illicit affairs                 10.00          10.0
# 2  evermore  no body, no crime (ft. HAIM)                 10.00          10.0
# 3  folklore                      cardigan                  9.80          10.0
# 4  folklore             my tears ricochet                  9.54          10.0
# 5  evermore                        willow                  9.52          10.0
#
#    Emotional Impact  Messaging  Lyricism  Nostalgia / Longetivity  \
# 1              10.0       10.0      10.0                     10.0
# 2              10.0       10.0      10.0                     10.0
# 3              10.0        9.0      10.0                     10.0
# 4              10.0       10.0       9.0                     10.0
# 5              10.0        9.0       9.0                      9.0
#
#    Overall Sound  Total RAW Score  ... Nostalgia Overall Sound.1  \
# 1           10.0             60.0  ...      1.20            1.50
# 2           10.0             60.0  ...      1.20            1.50
# 3            9.0             58.0  ...      1.20            1.35
# 4            9.0             58.0  ...      1.20            1.35
# 5           10.0             57.0  ...      1.08            1.50
#
#   Single Released On Original Album Deluxe or TV Album Track First Release  \
# 1           False              True              False  8.10        2020.0
# 2            True              True              False  9.06        2020.0
# 3            True              True              False  8.02        2020.0
# 4           False              True              False  8.05        2020.0
# 5            True              True              False  9.01        2020.0
#
#   Re- Release                                     Favorite Lyric  \
# 1         NaN  "You taught me a secret language I can't speak...
# 2         NaN  "Good thing my daddy made me get a boating lic...
# 3         NaN                   "You drew stars around my scars"
# 4         NaN  "And if I'm dead to you, why are you at the wa...
# 5         NaN          "Every bait and switch was a work of art"
#
#                             Notes/Alternate Versions
# 1                          long pond studio sessions
# 2                                                NaN
# 3  long pond studio sessions; cabin in candleligh...
# 4                          long pond studio sessions
# 5  dancing witch version (Elvira remix); lonely w...
#
# [5 rows x 24 columns]

# %%
album_mapping = {
    "Debut \(Taylor Swift\).*": "Debut (Taylor Swift)",
    "Fearless.*": "Fearless",
    "Speak Now.*": "Speak Now",
    "Red.*": "Red",
    "1989.*": "1989",
    "Reputation.*": "Reputation",
    "Lover.*": "Lover",
    "folklore.*": "folklore",
    "evermore.*": "evermore",
    "Midnights.*": "Midnights",
    "The Tortured Poets Department.*": "The Tortured Poets Department",
    "SINGLE.*": "SINGLE:"
}

df['Album'] = df['Album'].replace(to_replace=album_mapping, regex=True)

unique_albums = df['Album'].unique()

# %%
descriptive_stats = df.groupby('Album').describe()
print(descriptive_stats)
# Out:
#                               Total Weighted Score                            \
#                                              count      mean       std   min
# Album
# 1989                                          21.0  3.494762  1.449405  1.75
# Debut (Taylor Swift)                          14.0  1.820000  1.001645  1.00
# Fearless                                      25.0  2.060400  1.441953  1.00
# Lover                                         19.0  4.676316  1.541310  1.86
# Midnights                                     22.0  4.593636  1.971684  1.92
# Red                                           29.0  3.931379  1.951567  1.60
# Reputation                                    15.0  4.452000  1.573432  2.64
# SINGLE:                                       13.0  3.856154  2.193169  1.00
# Speak Now                                     23.0  4.208696  1.965984  2.05
# The Tortured Poets Department                 31.0  6.037742  2.344396  1.79
# evermore                                      17.0  6.092941  2.918563  1.90
# folklore                                      17.0  7.594706  2.021126  2.87
#
#                                                           Enjoyability  \
#                                  25%   50%     75%    max        count
# Album
# 1989                           2.230  3.32  3.9700   6.40         21.0
# Debut (Taylor Swift)           1.320  1.39  1.8725   4.30         14.0
# Fearless                       1.300  1.66  1.8100   7.03         25.0
# Lover                          3.715  4.20  6.1750   6.85         19.0
# Midnights                      3.090  3.77  6.0225   9.14         22.0
# Red                            2.440  3.57  4.9800   9.42         29.0
# Reputation                     3.160  3.92  5.5950   7.91         15.0
# SINGLE:                        2.010  4.14  5.1200   7.73         13.0
# Speak Now                      2.705  3.40  5.2000   8.92         23.0
# The Tortured Poets Department  3.915  5.75  8.1700   9.49         31.0
# evermore                       3.720  5.73  9.0000  10.00         17.0
# folklore                       6.820  8.10  9.1500  10.00         17.0
#
#                                          ... First Release          \
#                                    mean  ...           75%     max
# Album                                    ...
# 1989                           2.571429  ...        2014.0  2023.0
# Debut (Taylor Swift)           1.714286  ...        2006.0  2006.0
# Fearless                       1.800000  ...        2010.0  2021.0
# Lover                          3.263158  ...        2019.0  2023.0
# Midnights                      4.318182  ...        2022.0  2023.0
# Red                            2.931034  ...        2021.0  2021.0
# Reputation                     3.400000  ...        2017.0  2017.0
# SINGLE:                        2.923077  ...        2019.0  2022.0
# Speak Now                      3.260870  ...        2016.5  2023.0
# The Tortured Poets Department  6.064516  ...        2024.0  2024.0
# evermore                       6.000000  ...        2020.0  2020.0
# folklore                       8.352941  ...        2020.0  2020.0
#
#                               Re- Release                               \
#                                     count       mean       std     min
# Album
# 1989                                 16.0  2022.8125  0.543906  2021.0
# Debut (Taylor Swift)                  0.0        NaN       NaN     NaN
# Fearless                             19.0  2021.0000  0.000000  2021.0
# Lover                                 0.0        NaN       NaN     NaN
# Midnights                             3.0  2023.0000  0.000000  2023.0
# Red                                  20.0  2021.0000  0.000000  2021.0
# Reputation                            0.0        NaN       NaN     NaN
# SINGLE:                               3.0  2023.0000  0.000000  2023.0
# Speak Now                            17.0  2023.0000  0.000000  2023.0
# The Tortured Poets Department         0.0        NaN       NaN     NaN
# evermore                              0.0        NaN       NaN     NaN
# folklore                              0.0        NaN       NaN     NaN
#
#
#                                   25%     50%     75%     max
# Album
# 1989                           2023.0  2023.0  2023.0  2023.0
# Debut (Taylor Swift)              NaN     NaN     NaN     NaN
# Fearless                       2021.0  2021.0  2021.0  2021.0
# Lover                             NaN     NaN     NaN     NaN
# Midnights                      2023.0  2023.0  2023.0  2023.0
# Red                            2021.0  2021.0  2021.0  2021.0
# Reputation                        NaN     NaN     NaN     NaN
# SINGLE:                        2023.0  2023.0  2023.0  2023.0
# Speak Now                      2023.0  2023.0  2023.0  2023.0
# The Tortured Poets Department     NaN     NaN     NaN     NaN
# evermore                          NaN     NaN     NaN     NaN
# folklore                          NaN     NaN     NaN     NaN
#
# [12 rows x 88 columns]

# %%
# Rename the column to avoid spaces
df.rename(columns={'Total Weighted Score': 'Total_Weighted_Score'}, inplace=True)

model = ols('Total_Weighted_Score ~ C(Album)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)

if anova_table.loc['C(Album)', 'PR(>F)'] < 0.05:  # Use .loc for safer indexing
    tukey = pairwise_tukeyhsd(endog=df['Total_Weighted_Score'], groups=df['Album'], alpha=0.05)
    print(tukey)
else:
    print("ANOVA was not significant; Tukey's HSD is not necessary.")
# Out:
#               sum_sq     df          F        PR(>F)
# C(Album)  565.866628   11.0  13.679855  3.929953e-20
# Residual  879.945443  234.0        NaN           NaN
#                        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================================================
#             group1                        group2            meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------------------------------
#                          1989          Debut (Taylor Swift)  -1.6748 0.3433 -3.8838 0.5342  False
#                          1989                      Fearless  -1.4344 0.3459 -3.3295 0.4607  False
#                          1989                         Lover   1.1816 0.7428 -0.8456 3.2087  False
#                          1989                     Midnights   1.0989 0.7839 -0.8543 3.0521  False
#                          1989                           Red   0.4366 0.9997 -1.3978 2.2711  False
#                          1989                    Reputation   0.9572 0.9496 -1.2071 3.1216  False
#                          1989                       SINGLE:   0.3614    1.0  -1.898 2.6208  False
#                          1989                     Speak Now   0.7139 0.9869 -1.2184 2.6463  False
#                          1989 The Tortured Poets Department    2.543 0.0004  0.7335 4.3524   True
#                          1989                      evermore   2.5982 0.0032  0.5094  4.687   True
#                          1989                      folklore   4.0999    0.0  2.0112 6.1887   True
#          Debut (Taylor Swift)                      Fearless   0.2404    1.0 -1.8967 2.3775  False
#          Debut (Taylor Swift)                         Lover   2.8563 0.0024  0.6013 5.1113   True
#          Debut (Taylor Swift)                     Midnights   2.7736 0.0023  0.5848 4.9625   True
#          Debut (Taylor Swift)                           Red   2.1114 0.0438  0.0278 4.1949   True
#          Debut (Taylor Swift)                    Reputation    2.632 0.0164  0.2528 5.0112   True
#          Debut (Taylor Swift)                       SINGLE:   2.0362 0.2202 -0.4298 4.5021  False
#          Debut (Taylor Swift)                     Speak Now   2.3887 0.0175  0.2185 4.5589   True
#          Debut (Taylor Swift) The Tortured Poets Department   4.2177    0.0  2.1562 6.2793   True
#          Debut (Taylor Swift)                      evermore   4.2729    0.0  1.9623 6.5835   True
#          Debut (Taylor Swift)                      folklore   5.7747    0.0  3.4641 8.0853   True
#                      Fearless                         Lover   2.6159 0.0009  0.6674 4.5645   True
#                      Fearless                     Midnights   2.5332 0.0007  0.6617 4.4048   True
#                      Fearless                           Red    1.871 0.0242  0.1237 3.6183   True
#                      Fearless                    Reputation   2.3916 0.0107  0.3006 4.4826   True
#                      Fearless                       SINGLE:   1.7958 0.2289 -0.3934 3.9849  False
#                      Fearless                     Speak Now   2.1483 0.0087  0.2985 3.9981   True
#                      Fearless The Tortured Poets Department   3.9773    0.0  2.2564 5.6983   True
#                      Fearless                      evermore   4.0325    0.0  2.0199 6.0452   True
#                      Fearless                      folklore   5.5343    0.0  3.5217 7.5469   True
#                         Lover                     Midnights  -0.0827    1.0 -2.0878 1.9224  False
#                         Lover                           Red  -0.7449 0.9783 -2.6346 1.1447  False
#                         Lover                    Reputation  -0.2243    1.0 -2.4356  1.987  False
#                         Lover                       SINGLE:  -0.8202 0.9904 -3.1246 1.4842  False
#                         Lover                     Speak Now  -0.4676 0.9998 -2.4524 1.5172  False
#                         Lover The Tortured Poets Department   1.3614 0.4038 -0.5039 3.2268  False
#                         Lover                      evermore   1.4166 0.5599 -0.7208  3.554  False
#                         Lover                      folklore   2.9184 0.0006   0.781 5.0558   True
#                     Midnights                           Red  -0.6623 0.9879 -2.4724 1.1479  False
#                     Midnights                    Reputation  -0.1416    1.0 -2.2854 2.0021  False
#                     Midnights                       SINGLE:  -0.7375  0.995 -2.9772 1.5022  False
#                     Midnights                     Speak Now  -0.3849    1.0 -2.2942 1.5243  False
#                     Midnights The Tortured Poets Department   1.4441 0.2474 -0.3407 3.2289  False
#                     Midnights                      evermore   1.4993 0.4141 -0.5681 3.5667  False
#                     Midnights                      folklore   3.0011 0.0002  0.9336 5.0685   True
#                           Red                    Reputation   0.5206 0.9995 -1.5156 2.5568  False
#                           Red                       SINGLE:  -0.0752    1.0 -2.2121 2.0617  False
#                           Red                     Speak Now   0.2773    1.0 -1.5103 2.0649  False
#                           Red The Tortured Poets Department   2.1064 0.0022  0.4524 3.7603   True
#                           Red                      evermore   2.1616 0.0166  0.2059 4.1172   True
#                           Red                      folklore   3.6633    0.0  1.7077  5.619   True
#                    Reputation                       SINGLE:  -0.5958 0.9997 -3.0219 1.8302  False
#                    Reputation                     Speak Now  -0.2433    1.0 -2.3681 1.8815  False
#                    Reputation The Tortured Poets Department   1.5857 0.2859 -0.4279 3.5994  False
#                    Reputation                      evermore   1.6409 0.4179  -0.627 3.9089  False
#                    Reputation                      folklore   3.1427 0.0005  0.8747 5.4107   True
#                       SINGLE:                     Speak Now   0.3525    1.0  -1.869 2.5741  False
#                       SINGLE: The Tortured Poets Department   2.1816 0.0366  0.0661 4.2971   True
#                       SINGLE:                      evermore   2.2368 0.0814  -0.122 4.5956  False
#                       SINGLE:                      folklore   3.7386    0.0  1.3797 6.0974   True
#                     Speak Now The Tortured Poets Department    1.829 0.0341  0.0671  3.591   True
#                     Speak Now                      evermore   1.8842 0.1044 -0.1635  3.932  False
#                     Speak Now                      folklore    3.386    0.0  1.3383 5.4338   True
# The Tortured Poets Department                      evermore   0.0552    1.0  -1.877 1.9874  False
# The Tortured Poets Department                      folklore    1.557 0.2531 -0.3752 3.4891  False
#                      evermore                      folklore   1.5018 0.5097 -0.6942 3.6977  False
# -------------------------------------------------------------------------------------------------
